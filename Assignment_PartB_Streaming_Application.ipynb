# %% [markdown]
# # Task 1. Processing Data Stream (45%)
# ## Streaming Application

# %%
import json
from pymongo import MongoClient
from pyspark.sql import SparkSession
import geohash2
from pprint import pprint
import csv
from datetime import datetime
from collections import defaultdict

import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-10_2.12:3.3.0,org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0 pyspark-shell'

host_ip = "192.168.100.7"

client = MongoClient(host_ip, 27017)

db = client["fit3182_asgn3"]
db.stream_data.drop()
collection = db["stream_data"]

# %%
spark = (
    SparkSession.builder
    .master('local[*]')
    .appName('Streaming Climate and Hotspot Data')
    .getOrCreate()
)

# %%
topic = 'Climate_Hotspot_Stream'

# %%
kafka_sdf = (
    spark.readStream
    .format('kafka')
    .option('kafka.bootstrap.servers', f'{host_ip}:9092')
    .option('subscribe', topic)
    .option('startingOffsets', 'latest') #start consuming messages from the latest offset available in the topic when the streaming query starts
    .load()
)

# %%
climate_sdf = kafka_sdf.select('value')

# %%
def process_batch(df, epoch_id):
    
    # Collect streaming data
    print("Batch " + str(epoch_id))
    batch_data_list = []
    data = df.collect()

    # Loop through streaming dataframe and decode data
    for row in data:
        json_dict = json.loads(row.value.decode("utf-8"))
        json_data = json.dumps(json_dict)
        batch_data_list.append(json_data)

    # Compute geohash of precision 3 and 5
    result = []
    for json_str in batch_data_list:
        data = json.loads(json_str)
        latitude = data['latitude']
        longitude = data['longitude']
        geohash3 = geohash2.encode(float(latitude), float(longitude), precision=3)
        geohash5 = geohash2.encode(float(latitude), float(longitude), precision=5)
        data['geohash3'] = geohash3
        data['geohash5'] = geohash5
        result.append(data)

    # Append data as json object into geohash_result json document
    geohash_result = [json.dumps(data) for data in result]

    climate_geohash3 = ''
    climate_record = {}
    fire_cause = ''

    # Loop through all json strings in geohash_result
    for json_str in geohash_result:
        
        # Load json string as json object
        data = json.loads(json_str)
        
        # If data is from climate_streaming dataset
        if data['producer'] == 'Climate':
            
            # Climate record's geohash3 value
            climate_geohash3 = data['geohash3'] 
            
            # Get the current climate record
            climate_record = data
            
            # Check fire cause
            if int(climate_record['air_temperature_celcius']) > 20 and int(climate_record['GHI_w/m2']) > 180:
                fire_cause ='natural'
            else:
                fire_cause ='other'
            
            # Break if found one climate record as we only get one per batch
            break

    # If at least one climate record exists in the batch
    if climate_geohash3 != '':
        
        # Add hotspot list for the climate record
        climate_record['hotspots'] = []

        # If producer is not Climate, append the hotspot record (from producer AQUA and TERRA) into hotspot list
        for json_str in geohash_result:
            data = json.loads(json_str)
            if data['producer'] != "Climate":
                climate_record['hotspots'].append(data)
    
    # Check if climate record exists
    if climate_geohash3 != '':
        grouped_hotspots = defaultdict(list)
        
        # if climate's hotspot list is not empty, append all hotspots with the same geohash3 as the climate record,
        # group the hotspots with the same geohash5 together
        for hotspot in climate_record['hotspots']:
            if hotspot['geohash3']==climate_geohash3:
                geohash5 = hotspot['geohash5']
                grouped_hotspots[geohash5].append(hotspot)

        # Add into fire_event list if hotspot has the same geohash3 value as climate, 
        # for hotspot records that has the same geohash5 value, we assume that they are the same fire event, 
        # hence get their average (for confidence and surface_temperature_celsius) and 
        # get the last record's latitude, llongitude and datetime
        # finallt append to the fire_event list
        fire_event = []
        for geohash5, hotspots in grouped_hotspots.items():
            if len(hotspots) > 1:
                total_confidence = 0
                total_surface_temperature = 0
                for hotspot in hotspots:
                    total_confidence += int(hotspot['confidence'])
                    total_surface_temperature += int(hotspot['surface_temperature_celcius'])

                average_confidence = total_confidence / len(hotspots)
                average_surface_temperature = total_surface_temperature / len(hotspots)
                
                fire_event.append({
                    'hotspot_geohash5': geohash5,
                    'confidence': average_confidence,
                    'surface_temperature_celcius': average_surface_temperature,
                    'latitude': hotspots[-1]['latitude'],
                    'longitude': hotspots[-1]['longitude'],
                    'datetime': hotspots[-1]['datetime'],
                    'fire_cause': fire_cause
                })
            else:
                fire_event.append({
                    'hotspot_geohash5': geohash5,
                    'confidence': hotspots[0]['confidence'], #hotspots[0] is used to access the first hotspot document in the group when there is only one hotspot with a specific geohash5 value.
                    'surface_temperature_celcius': hotspots[0]['surface_temperature_celcius'],
                    'latitude': hotspots[0]['latitude'],
                    'longitude': hotspots[0]['longitude'],
                    'datetime': hotspots[0]['datetime'],
                    'fire_cause': fire_cause
                })

        climate_record['fire_event'] = fire_event

    pprint(climate_record)
    
    # Insert into mongoDB
    if climate_record != {}:
        collection.insert_one(climate_record)

# %%
writer = (
    climate_sdf.writeStream.format("Console")
    .option("checkpointLocation", "./climate_sdf_checkpoints")
    .outputMode('append')
    .trigger(processingTime='10 seconds')
    .foreachBatch(process_batch)
)

# %%
try:
    query = writer.start()
    query.awaitTermination()
except KeyboardInterrupt:
    print('Interrupted by CTRL-C. Stopping query.')
finally:
    query.stop()
# Out:
# Batch 3789
# {'GHI_w/m2': '200',
#  'air_temperature_celcius': '24',
#  'date': '18/01/2023',
#  'fire_event': [{'confidence': 81.91666666666667,
#                  'datetime': '2023-01-08T14:24:00',
#                  'fire_cause': 'natural',
#                  'hotspot_geohash5': 'r364j',
#                  'latitude': '-37.605',
#                  'longitude': '149.302',
#                  'surface_temperature_celcius': 55.083333333333336},
#                 {'confidence': 64.6,
#                  'datetime': '2023-01-06T19:12:00',
#                  'fire_cause': 'natural',
#                  'hotspot_geohash5': 'r361v',
#                  'latitude': '-37.623',
#                  'longitude': '149.323',
#                  'surface_temperature_celcius': 49.8},
#                 {'confidence': 75.25,
#                  'datetime': '2023-01-06T14:24:00',
#                  'fire_cause': 'natural',
#                  'hotspot_geohash5': 'r361y',
#                  'latitude': '-37.658',
#                  'longitude': '149.339',
#                  'surface_temperature_celcius': 48.25},
#                 {'confidence': 88.25,
#                  'datetime': '2023-01-06T04:48:00',
#                  'fire_cause': 'natural',
#                  'hotspot_geohash5': 'r364n',
#                  'latitude': '-37.58',
#                  'longitude': '149.331',
#                  'surface_temperature_celcius': 49.25},
#                 {'confidence': 82.0,
#                  'datetime': '2023-01-07T19:12:00',
#                  'fire_cause': 'natural',
#                  'hotspot_geohash5': 'r361u',
#                  'latitude': '-37.642',
#                  'longitude': '149.263',
#                  'surface_temperature_celcius': 53.5},
#                 {'confidence': 72.5,
#                  'datetime': '2023-01-08T04:48:00',
#                  'fire_cause': 'natural',
#                  'hotspot_geohash5': 'r365q',
#                  'latitude': '-37.384',
#                  'longitude': '149.336',
#                  'surface_temperature_celcius': 45.0},
#                 {'confidence': 93.66666666666667,
#                  'datetime': '2023-01-08T00:00:00',
#                  'fire_cause': 'natural',
#                  'hotspot_geohash5': 'r361g',
#                  'latitude': '-37.634',
#                  'longitude': '149.237',
#                  'surface_temperature_celcius': 56.0},
#                 {'confidence': '73',
#                  'datetime': '2023-01-08T09:36:00',
#                  'fire_cause': 'natural',
#                  'hotspot_geohash5': 'r365m',
#                  'latitude': '-37.389',
#                  'longitude': '149.311',
#                  'surface_temperature_celcius': '50'}],
#  'geohash3': 'r36',
#  'geohash5': 'r361v',
#  'hotspots': [{'confidence': '67',
#                'datetime': '2023-01-17T00:00:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mvu',
#                'latitude': '-36.942',
#                'longitude': '143.292',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '100',
#                'datetime': '2023-01-16T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.608',
#                'longitude': '149.292',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '55'},
#               {'confidence': '89',
#                'datetime': '2023-01-17T04:48:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mvu',
#                'latitude': '-36.94',
#                'longitude': '143.281',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '69'},
#               {'confidence': '68',
#                'datetime': '2023-01-16T14:24:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.605',
#                'longitude': '149.308',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '43'},
#               {'confidence': '51',
#                'datetime': '2023-01-17T09:36:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mvu',
#                'latitude': '-36.943',
#                'longitude': '143.286',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '29'},
#               {'confidence': '52',
#                'datetime': '2023-01-16T19:12:00',
#                'geohash3': 'r1v',
#                'geohash5': 'r1vhf',
#                'latitude': '-34.282',
#                'longitude': '142.121',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '80',
#                'datetime': '2023-01-17T14:24:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mvu',
#                'latitude': '-36.941',
#                'longitude': '143.268',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '37'},
#               {'confidence': '100',
#                'datetime': '2023-01-17T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.606',
#                'longitude': '149.312',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '87'},
#               {'confidence': '100',
#                'datetime': '2023-01-17T19:12:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mvu',
#                'latitude': '-36.939',
#                'longitude': '143.28',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '59'},
#               {'confidence': '64',
#                'datetime': '2023-01-17T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.605',
#                'longitude': '149.326',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '44'},
#               {'confidence': '86',
#                'datetime': '2023-01-18T00:00:00',
#                'geohash3': 'r1q',
#                'geohash5': 'r1q88',
#                'latitude': '-37.863',
#                'longitude': '144.17',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '60'},
#               {'confidence': '97',
#                'datetime': '2023-01-17T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.61',
#                'longitude': '149.307',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '80'},
#               {'confidence': '68',
#                'datetime': '2023-01-18T04:48:00',
#                'geohash3': 'r1r',
#                'geohash5': 'r1rnz',
#                'latitude': '-36.759',
#                'longitude': '145.179',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '52'},
#               {'confidence': '62',
#                'datetime': '2023-01-18T09:36:00',
#                'geohash3': 'r1r',
#                'geohash5': 'r1rnz',
#                'latitude': '-36.758',
#                'longitude': '145.19',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '51'},
#               {'confidence': '51',
#                'datetime': '2023-01-02T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361v',
#                'latitude': '-37.623',
#                'longitude': '149.323',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '38'},
#               {'confidence': '65',
#                'datetime': '2023-01-02T04:48:00',
#                'geohash3': 'r1j',
#                'geohash5': 'r1jxt',
#                'latitude': '-38.038',
#                'longitude': '142.986',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '40'},
#               {'confidence': '92',
#                'datetime': '2023-01-02T09:36:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1m0p',
#                'latitude': '-37.95',
#                'longitude': '142.366',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '70'},
#               {'confidence': '78',
#                'datetime': '2023-01-02T00:00:00',
#                'geohash3': 'r1r',
#                'geohash5': 'r1r0h',
#                'latitude': '-37.966',
#                'longitude': '145.051',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '68'},
#               {'confidence': '83',
#                'datetime': '2023-01-02T14:24:00',
#                'geohash3': 'r30',
#                'geohash5': 'r30ws',
#                'latitude': '-38.231',
#                'longitude': '147.172',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '60'},
#               {'confidence': '82',
#                'datetime': '2023-01-02T04:48:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1tvv',
#                'latitude': '-35.541',
#                'longitude': '143.311',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '63'},
#               {'confidence': '53',
#                'datetime': '2023-01-02T19:12:00',
#                'geohash3': 'r1r',
#                'geohash5': 'r1r23',
#                'latitude': '-37.903',
#                'longitude': '145.25',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '44'},
#               {'confidence': '67',
#                'datetime': '2023-01-02T09:36:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1tvt',
#                'latitude': '-35.554',
#                'longitude': '143.307',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '53'},
#               {'confidence': '50',
#                'datetime': '2023-01-03T00:00:00',
#                'geohash3': 'r1n',
#                'geohash5': 'r1nru',
#                'latitude': '-37.987',
#                'longitude': '144.005',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '38'},
#               {'confidence': '86',
#                'datetime': '2023-01-02T14:24:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1tvv',
#                'latitude': '-35.543',
#                'longitude': '143.316',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '67'},
#               {'confidence': '67',
#                'datetime': '2023-01-03T04:48:00',
#                'geohash3': 'r1u',
#                'geohash5': 'r1uub',
#                'latitude': '-34.289',
#                'longitude': '141.712',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '80',
#                'datetime': '2023-01-02T19:12:00',
#                'geohash3': 'r1r',
#                'geohash5': 'r1r1m',
#                'latitude': '-37.708',
#                'longitude': '145.1',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '87',
#                'datetime': '2023-01-03T09:36:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.294',
#                'longitude': '146.149',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '61'},
#               {'confidence': '65',
#                'datetime': '2023-01-03T00:00:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1tjj',
#                'latitude': '-35.646',
#                'longitude': '142.282',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '32'},
#               {'confidence': '81',
#                'datetime': '2023-01-03T14:24:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.285',
#                'longitude': '146.151',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '72',
#                'datetime': '2023-01-03T04:48:00',
#                'geohash3': 'r1n',
#                'geohash5': 'r1npr',
#                'latitude': '-38.075',
#                'longitude': '143.76',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '46'},
#               {'confidence': '84',
#                'datetime': '2023-01-03T19:12:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xcw',
#                'latitude': '-36.277',
#                'longitude': '146.165',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '58'},
#               {'confidence': '94',
#                'datetime': '2023-01-03T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361y',
#                'latitude': '-37.636',
#                'longitude': '149.33',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '43'},
#               {'confidence': '86',
#                'datetime': '2023-01-04T00:00:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.275',
#                'longitude': '146.154',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '60'},
#               {'confidence': '69',
#                'datetime': '2023-01-03T14:24:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361y',
#                'latitude': '-37.624',
#                'longitude': '149.332',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '33'},
#               {'confidence': '77',
#                'datetime': '2023-01-04T04:48:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.273',
#                'longitude': '146.155',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '36'},
#               {'confidence': '62',
#                'datetime': '2023-01-03T19:12:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1m0y',
#                'latitude': '-37.82',
#                'longitude': '142.323',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '100',
#                'datetime': '2023-01-04T09:36:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.284',
#                'longitude': '146.145',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '93',
#                'datetime': '2023-01-04T00:00:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1m2d',
#                'latitude': '-37.875',
#                'longitude': '142.51',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '73'},
#               {'confidence': '100',
#                'datetime': '2023-01-04T14:24:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.282',
#                'longitude': '146.157',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '71'},
#               {'confidence': '84',
#                'datetime': '2023-01-04T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364n',
#                'latitude': '-37.608',
#                'longitude': '149.328',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '55'},
#               {'confidence': '100',
#                'datetime': '2023-01-04T19:12:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.293',
#                'longitude': '146.148',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '52'},
#               {'confidence': '95',
#                'datetime': '2023-01-04T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.613',
#                'longitude': '149.305',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '75'},
#               {'confidence': '56',
#                'datetime': '2023-01-05T00:00:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.291',
#                'longitude': '146.159',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '40'},
#               {'confidence': '59',
#                'datetime': '2023-01-04T14:24:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361y',
#                'latitude': '-37.644',
#                'longitude': '149.346',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '55'},
#               {'confidence': '52',
#                'datetime': '2023-01-05T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361v',
#                'latitude': '-37.635',
#                'longitude': '149.303',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '47'},
#               {'confidence': '90',
#                'datetime': '2023-01-04T19:12:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361v',
#                'latitude': '-37.624',
#                'longitude': '149.314',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '66'},
#               {'confidence': '100',
#                'datetime': '2023-01-05T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364n',
#                'latitude': '-37.591',
#                'longitude': '149.33',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '53'},
#               {'confidence': '75',
#                'datetime': '2023-01-05T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361y',
#                'latitude': '-37.661',
#                'longitude': '149.327',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '56'},
#               {'confidence': '51',
#                'datetime': '2023-01-05T14:24:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.59',
#                'longitude': '149.31',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '42'},
#               {'confidence': '79',
#                'datetime': '2023-01-05T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361v',
#                'latitude': '-37.649',
#                'longitude': '149.322',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '60'},
#               {'confidence': '64',
#                'datetime': '2023-01-05T19:12:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361u',
#                'latitude': '-37.633',
#                'longitude': '149.264',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '42'},
#               {'confidence': '93',
#                'datetime': '2023-01-05T09:36:00',
#                'geohash3': 'r1n',
#                'geohash5': 'r1nx3',
#                'latitude': '-38.057',
#                'longitude': '144.211',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '73'},
#               {'confidence': '100',
#                'datetime': '2023-01-06T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364n',
#                'latitude': '-37.585',
#                'longitude': '149.336',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '60',
#                'datetime': '2023-01-05T14:24:00',
#                'geohash3': 'r1n',
#                'geohash5': 'r1nx9',
#                'latitude': '-38.046',
#                'longitude': '144.201',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '48'},
#               {'confidence': '69',
#                'datetime': '2023-01-06T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364n',
#                'latitude': '-37.58',
#                'longitude': '149.331',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '35'},
#               {'confidence': '82',
#                'datetime': '2023-01-05T19:12:00',
#                'geohash3': 'r1n',
#                'geohash5': 'r1nx9',
#                'latitude': '-38.048',
#                'longitude': '144.213',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '55'},
#               {'confidence': '100',
#                'datetime': '2023-01-06T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.583',
#                'longitude': '149.316',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '49'},
#               {'confidence': '82',
#                'datetime': '2023-01-06T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361y',
#                'latitude': '-37.651',
#                'longitude': '149.345',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '64'},
#               {'confidence': '61',
#                'datetime': '2023-01-06T14:24:00',
#                'geohash3': 'r36',
#                'geohash5': 'r365q',
#                'latitude': '-37.38',
#                'longitude': '149.334',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '31'},
#               {'confidence': '53',
#                'datetime': '2023-01-06T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361y',
#                'latitude': '-37.63',
#                'longitude': '149.335',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '57'},
#               {'confidence': '62',
#                'datetime': '2023-01-06T19:12:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.602',
#                'longitude': '149.295',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '33'},
#               {'confidence': '92',
#                'datetime': '2023-01-06T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361y',
#                'latitude': '-37.627',
#                'longitude': '149.33',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '42'},
#               {'confidence': '64',
#                'datetime': '2023-01-07T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.598',
#                'longitude': '149.29',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '32'},
#               {'confidence': '78',
#                'datetime': '2023-01-06T14:24:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361y',
#                'latitude': '-37.658',
#                'longitude': '149.339',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '36'},
#               {'confidence': '84',
#                'datetime': '2023-01-07T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.596',
#                'longitude': '149.319',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '38'},
#               {'confidence': '51',
#                'datetime': '2023-01-06T19:12:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361v',
#                'latitude': '-37.623',
#                'longitude': '149.323',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '38'},
#               {'confidence': '81',
#                'datetime': '2023-01-07T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361g',
#                'latitude': '-37.63',
#                'longitude': '149.232',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '42'},
#               {'confidence': '65',
#                'datetime': '2023-01-07T00:00:00',
#                'geohash3': 'r1j',
#                'geohash5': 'r1jxt',
#                'latitude': '-38.038',
#                'longitude': '142.986',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '40'},
#               {'confidence': '100',
#                'datetime': '2023-01-07T14:24:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361g',
#                'latitude': '-37.644',
#                'longitude': '149.233',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '55'},
#               {'confidence': '92',
#                'datetime': '2023-01-07T04:48:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1m0p',
#                'latitude': '-37.95',
#                'longitude': '142.366',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '70'},
#               {'confidence': '100',
#                'datetime': '2023-01-07T19:12:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361u',
#                'latitude': '-37.642',
#                'longitude': '149.263',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '65'},
#               {'confidence': '83',
#                'datetime': '2023-01-07T09:36:00',
#                'geohash3': 'r30',
#                'geohash5': 'r30ws',
#                'latitude': '-38.231',
#                'longitude': '147.172',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '60'},
#               {'confidence': '100',
#                'datetime': '2023-01-08T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361g',
#                'latitude': '-37.634',
#                'longitude': '149.237',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '71'},
#               {'confidence': '53',
#                'datetime': '2023-01-07T14:24:00',
#                'geohash3': 'r1r',
#                'geohash5': 'r1r23',
#                'latitude': '-37.903',
#                'longitude': '145.25',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '44'},
#               {'confidence': '84',
#                'datetime': '2023-01-08T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r365q',
#                'latitude': '-37.384',
#                'longitude': '149.336',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '59'},
#               {'confidence': '50',
#                'datetime': '2023-01-07T19:12:00',
#                'geohash3': 'r1n',
#                'geohash5': 'r1nru',
#                'latitude': '-37.987',
#                'longitude': '144.005',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '38'},
#               {'confidence': '73',
#                'datetime': '2023-01-08T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r365m',
#                'latitude': '-37.389',
#                'longitude': '149.311',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '50'},
#               {'confidence': '67',
#                'datetime': '2023-01-08T00:00:00',
#                'geohash3': 'r1u',
#                'geohash5': 'r1uub',
#                'latitude': '-34.289',
#                'longitude': '141.712',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '98',
#                'datetime': '2023-01-08T14:24:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.605',
#                'longitude': '149.302',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '83'},
#               {'confidence': '87',
#                'datetime': '2023-01-08T04:48:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.294',
#                'longitude': '146.149',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '61'}],
#  'latitude': '-37.635',
#  'longitude': '149.303',
#  'max_wind_speed': '15.9',
#  'precipitation ': ' 0.00I',
#  'producer': 'Climate',
#  'relative_humidity': '53.4',
#  'windspeed_knots': '9.9'}
# Batch 3790
# {'GHI_w/m2': '154',
#  'air_temperature_celcius': '19',
#  'date': '10/01/2023',
#  'fire_event': [{'confidence': 85.71428571428571,
#                  'datetime': '2023-01-09T19:12:00',
#                  'fire_cause': 'other',
#                  'hotspot_geohash5': 'r1xct',
#                  'latitude': '-36.291',
#                  'longitude': '146.159',
#                  'surface_temperature_celcius': 52.42857142857143},
#                 {'confidence': '84',
#                  'datetime': '2023-01-08T14:24:00',
#                  'fire_cause': 'other',
#                  'hotspot_geohash5': 'r1xcw',
#                  'latitude': '-36.277',
#                  'longitude': '146.165',
#                  'surface_temperature_celcius': '58'}],
#  'geohash3': 'r1x',
#  'geohash5': 'r1xct',
#  'hotspots': [{'confidence': '81',
#                'datetime': '2023-01-08T19:12:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361u',
#                'latitude': '-37.627',
#                'longitude': '149.261',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '57'},
#               {'confidence': '81',
#                'datetime': '2023-01-08T09:36:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.285',
#                'longitude': '146.151',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '84',
#                'datetime': '2023-01-09T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361v',
#                'latitude': '-37.623',
#                'longitude': '149.284',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '61'},
#               {'confidence': '84',
#                'datetime': '2023-01-08T14:24:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xcw',
#                'latitude': '-36.277',
#                'longitude': '146.165',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '58'},
#               {'confidence': '99',
#                'datetime': '2023-01-09T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.6',
#                'longitude': '149.325',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '86'},
#               {'confidence': '86',
#                'datetime': '2023-01-08T19:12:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.275',
#                'longitude': '146.154',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '60'},
#               {'confidence': '69',
#                'datetime': '2023-01-09T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364h',
#                'latitude': '-37.61',
#                'longitude': '149.279',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '48'},
#               {'confidence': '77',
#                'datetime': '2023-01-09T00:00:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.273',
#                'longitude': '146.155',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '36'},
#               {'confidence': '60',
#                'datetime': '2023-01-09T14:24:00',
#                'geohash3': 'r32',
#                'geohash5': 'r321b',
#                'latitude': '-37.637',
#                'longitude': '146.288',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '42'},
#               {'confidence': '100',
#                'datetime': '2023-01-09T04:48:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.284',
#                'longitude': '146.145',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '83',
#                'datetime': '2023-01-09T19:12:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364h',
#                'latitude': '-37.608',
#                'longitude': '149.282',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '58'},
#               {'confidence': '100',
#                'datetime': '2023-01-09T09:36:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.282',
#                'longitude': '146.157',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '71'},
#               {'confidence': '87',
#                'datetime': '2023-01-10T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361v',
#                'latitude': '-37.62',
#                'longitude': '149.294',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '63'},
#               {'confidence': '100',
#                'datetime': '2023-01-09T14:24:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.293',
#                'longitude': '146.148',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '52'},
#               {'confidence': '95',
#                'datetime': '2023-01-10T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361u',
#                'latitude': '-37.618',
#                'longitude': '149.281',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '76'},
#               {'confidence': '56',
#                'datetime': '2023-01-09T19:12:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xct',
#                'latitude': '-36.291',
#                'longitude': '146.159',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '40'},
#               {'confidence': '81',
#                'datetime': '2023-01-10T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.61',
#                'longitude': '149.296',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '56'},
#               {'confidence': '52',
#                'datetime': '2023-01-10T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361v',
#                'latitude': '-37.635',
#                'longitude': '149.303',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '47'}],
#  'latitude': '-36.285',
#  'longitude': '146.151',
#  'max_wind_speed': '8.9',
#  'precipitation ': ' 0.00I',
#  'producer': 'Climate',
#  'relative_humidity': '56.3',
#  'windspeed_knots': '5.8'}
# Batch 3791
# {}
# Batch 3792
# {'GHI_w/m2': '150',
#  'air_temperature_celcius': '18',
#  'date': '12/01/2023',
#  'fire_event': [],
#  'geohash3': 'r1x',
#  'geohash5': 'r1xct',
#  'hotspots': [{'confidence': '64',
#                'datetime': '2023-01-11T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r365q',
#                'latitude': '-37.382',
#                'longitude': '149.341',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '41'},
#               {'confidence': '100',
#                'datetime': '2023-01-10T19:12:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364n',
#                'latitude': '-37.585',
#                'longitude': '149.336',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '53',
#                'datetime': '2023-01-11T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364h',
#                'latitude': '-37.611',
#                'longitude': '149.277',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '38'},
#               {'confidence': '69',
#                'datetime': '2023-01-11T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364n',
#                'latitude': '-37.58',
#                'longitude': '149.331',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '35'},
#               {'confidence': '100',
#                'datetime': '2023-01-11T14:24:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.608',
#                'longitude': '149.292',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '55'},
#               {'confidence': '100',
#                'datetime': '2023-01-11T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.583',
#                'longitude': '149.316',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '49'},
#               {'confidence': '68',
#                'datetime': '2023-01-11T19:12:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.605',
#                'longitude': '149.308',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '43'},
#               {'confidence': '61',
#                'datetime': '2023-01-11T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r365q',
#                'latitude': '-37.38',
#                'longitude': '149.334',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '31'},
#               {'confidence': '52',
#                'datetime': '2023-01-12T00:00:00',
#                'geohash3': 'r1v',
#                'geohash5': 'r1vhf',
#                'latitude': '-34.282',
#                'longitude': '142.121',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '62',
#                'datetime': '2023-01-11T14:24:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.602',
#                'longitude': '149.295',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '33'}],
#  'latitude': '-36.275',
#  'longitude': '146.154',
#  'max_wind_speed': '14',
#  'precipitation ': ' 0.00I',
#  'producer': 'Climate',
#  'relative_humidity': '53.3',
#  'windspeed_knots': '7.9'}
# Batch 3793
# {'GHI_w/m2': '179',
#  'air_temperature_celcius': '22',
#  'date': '13/01/2023',
#  'fire_event': [],
#  'geohash3': 'r1x',
#  'geohash5': 'r1xct',
#  'hotspots': [{'confidence': '100',
#                'datetime': '2023-01-12T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.606',
#                'longitude': '149.312',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '87'},
#               {'confidence': '64',
#                'datetime': '2023-01-11T19:12:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.598',
#                'longitude': '149.29',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '32'},
#               {'confidence': '64',
#                'datetime': '2023-01-12T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.605',
#                'longitude': '149.326',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '44'},
#               {'confidence': '84',
#                'datetime': '2023-01-12T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.596',
#                'longitude': '149.319',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '38'},
#               {'confidence': '97',
#                'datetime': '2023-01-12T14:24:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.61',
#                'longitude': '149.307',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '80'},
#               {'confidence': '81',
#                'datetime': '2023-01-12T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361g',
#                'latitude': '-37.63',
#                'longitude': '149.232',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '42'},
#               {'confidence': '99',
#                'datetime': '2023-01-12T19:12:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.609',
#                'longitude': '149.32',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '84'},
#               {'confidence': '100',
#                'datetime': '2023-01-12T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361g',
#                'latitude': '-37.644',
#                'longitude': '149.233',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '55'},
#               {'confidence': '50',
#                'datetime': '2023-01-13T00:00:00',
#                'geohash3': 'r33',
#                'geohash5': 'r333q',
#                'latitude': '-37.749',
#                'longitude': '148.297',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '42'},
#               {'confidence': '100',
#                'datetime': '2023-01-12T14:24:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361u',
#                'latitude': '-37.642',
#                'longitude': '149.263',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '65'}],
#  'latitude': '-36.273',
#  'longitude': '146.155',
#  'max_wind_speed': '13',
#  'precipitation ': ' 0.08G',
#  'producer': 'Climate',
#  'relative_humidity': '56.3',
#  'windspeed_knots': '8'}
# Batch 3794
# {'GHI_w/m2': '157',
#  'air_temperature_celcius': '19',
#  'date': '14/01/2023',
#  'fire_event': [],
#  'geohash3': 'r1x',
#  'geohash5': 'r1xct',
#  'hotspots': [{'confidence': '84',
#                'datetime': '2023-01-13T04:48:00',
#                'geohash3': 'r1q',
#                'geohash5': 'r1q8h',
#                'latitude': '-37.946',
#                'longitude': '144.342',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '60'},
#               {'confidence': '100',
#                'datetime': '2023-01-12T19:12:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361g',
#                'latitude': '-37.634',
#                'longitude': '149.237',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '71'},
#               {'confidence': '93',
#                'datetime': '2023-01-13T09:36:00',
#                'geohash3': 'r1q',
#                'geohash5': 'r1q8h',
#                'latitude': '-37.945',
#                'longitude': '144.354',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '73'},
#               {'confidence': '84',
#                'datetime': '2023-01-13T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r365q',
#                'latitude': '-37.384',
#                'longitude': '149.336',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '59'},
#               {'confidence': '68',
#                'datetime': '2023-01-13T14:24:00',
#                'geohash3': 'r1j',
#                'geohash5': 'r1jz4',
#                'latitude': '-38.141',
#                'longitude': '143.183',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '46'},
#               {'confidence': '73',
#                'datetime': '2023-01-13T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r365m',
#                'latitude': '-37.389',
#                'longitude': '149.311',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '50'},
#               {'confidence': '63',
#                'datetime': '2023-01-13T19:12:00',
#                'geohash3': 'r1r',
#                'geohash5': 'r1rjf',
#                'latitude': '-36.952',
#                'longitude': '144.972',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '60'},
#               {'confidence': '98',
#                'datetime': '2023-01-13T09:36:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.605',
#                'longitude': '149.302',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '83'},
#               {'confidence': '70',
#                'datetime': '2023-01-14T00:00:00',
#                'geohash3': 'r1u',
#                'geohash5': 'r1ucp',
#                'latitude': '-34.965',
#                'longitude': '142.031',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '55'},
#               {'confidence': '81',
#                'datetime': '2023-01-13T14:24:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361u',
#                'latitude': '-37.627',
#                'longitude': '149.261',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '57'}],
#  'latitude': '-36.284',
#  'longitude': '146.145',
#  'max_wind_speed': '18.1',
#  'precipitation ': ' 0.31G',
#  'producer': 'Climate',
#  'relative_humidity': '54.1',
#  'windspeed_knots': '11.2'}
# Batch 3795
# {'GHI_w/m2': '145',
#  'air_temperature_celcius': '17',
#  'date': '15/01/2023',
#  'fire_event': [],
#  'geohash3': 'r1x',
#  'geohash5': 'r1xct',
#  'hotspots': [{'confidence': '84',
#                'datetime': '2023-01-14T04:48:00',
#                'geohash3': 'r1p',
#                'geohash5': 'r1pxc',
#                'latitude': '-37.978',
#                'longitude': '145.623',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '59'},
#               {'confidence': '84',
#                'datetime': '2023-01-13T19:12:00',
#                'geohash3': 'r36',
#                'geohash5': 'r361v',
#                'latitude': '-37.623',
#                'longitude': '149.284',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '61'},
#               {'confidence': '88',
#                'datetime': '2023-01-14T09:36:00',
#                'geohash3': 'r1p',
#                'geohash5': 'r1pxf',
#                'latitude': '-37.976',
#                'longitude': '145.649',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '64'},
#               {'confidence': '99',
#                'datetime': '2023-01-14T00:00:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364j',
#                'latitude': '-37.6',
#                'longitude': '149.325',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '86'},
#               {'confidence': '85',
#                'datetime': '2023-01-14T14:24:00',
#                'geohash3': 'r1q',
#                'geohash5': 'r1qch',
#                'latitude': '-37.758',
#                'longitude': '144.693',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '59'},
#               {'confidence': '69',
#                'datetime': '2023-01-14T04:48:00',
#                'geohash3': 'r36',
#                'geohash5': 'r364h',
#                'latitude': '-37.61',
#                'longitude': '149.279',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '48'},
#               {'confidence': '87',
# ...
#                'longitude': '144.7505',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '39'}],
#  'latitude': '-37.614',
#  'longitude': '143.451',
#  'max_wind_speed': '12',
#  'precipitation ': ' 0.00I',
#  'producer': 'Climate',
#  'relative_humidity': '60.2',
#  'windspeed_knots': '6.4'}
# Batch 3851
# {'GHI_w/m2': '158',
#  'air_temperature_celcius': '20',
#  'date': '12/03/2023',
#  'fire_event': [{'confidence': '85',
#                  'datetime': '2023-03-11T00:00:00',
#                  'fire_cause': 'other',
#                  'hotspot_geohash5': 'r1q2n',
#                  'latitude': '-37.926',
#                  'longitude': '144.0898',
#                  'surface_temperature_celcius': '59'}],
#  'geohash3': 'r1q',
#  'geohash5': 'r1q24',
#  'hotspots': [{'confidence': '69',
#                'datetime': '2023-03-10T09:36:00',
#                'geohash3': 'r1w',
#                'geohash5': 'r1w4z',
#                'latitude': '-36.059',
#                'longitude': '143.7718',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '44'},
#               {'confidence': '91',
#                'datetime': '2023-03-10T19:12:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mqz',
#                'latitude': '-36.7801',
#                'longitude': '142.7151',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '68'},
#               {'confidence': '85',
#                'datetime': '2023-03-11T00:00:00',
#                'geohash3': 'r1q',
#                'geohash5': 'r1q2n',
#                'latitude': '-37.926',
#                'longitude': '144.0898',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '59'},
#               {'confidence': '62',
#                'datetime': '2023-03-10T14:24:00',
#                'geohash3': 'r1w',
#                'geohash5': 'r1w5p',
#                'latitude': '-36.0201',
#                'longitude': '143.7775',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '41'},
#               {'confidence': '54',
#                'datetime': '2023-03-11T04:48:00',
#                'geohash3': 'r1s',
#                'geohash5': 'r1s8d',
#                'latitude': '-36.4422',
#                'longitude': '141.427',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '39'},
#               {'confidence': '62',
#                'datetime': '2023-03-10T19:12:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1m9t',
#                'latitude': '-37.6767',
#                'longitude': '142.9892',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '41'},
#               {'confidence': '64',
#                'datetime': '2023-03-11T00:00:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1m9t',
#                'latitude': '-37.6662',
#                'longitude': '142.9874',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '42'},
#               {'confidence': '59',
#                'datetime': '2023-03-11T09:36:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1t3u',
#                'latitude': '-36.251',
#                'longitude': '142.5651',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '40'},
#               {'confidence': '72',
#                'datetime': '2023-03-11T04:48:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1tg4',
#                'latitude': '-36.009',
#                'longitude': '143.185',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '39'},
#               {'confidence': '70',
#                'datetime': '2023-03-11T14:24:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mdn',
#                'latitude': '-37.5865',
#                'longitude': '143.0246',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '45'}],
#  'latitude': '-37.954',
#  'longitude': '143.918',
#  'max_wind_speed': '15.9',
#  'precipitation ': ' 0.01G',
#  'producer': 'Climate',
#  'relative_humidity': '59.7',
#  'windspeed_knots': '8.6'}
# Batch 3852
# {'GHI_w/m2': '168',
#  'air_temperature_celcius': '21',
#  'date': '13/03/2023',
#  'fire_event': [],
#  'geohash3': 'r1n',
#  'geohash5': 'r1nqc',
#  'hotspots': [{'confidence': '84',
#                'datetime': '2023-03-11T09:36:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1tc0',
#                'latitude': '-36.358',
#                'longitude': '143.113',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '52'},
#               {'confidence': '75',
#                'datetime': '2023-03-11T19:12:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mdn',
#                'latitude': '-37.5915',
#                'longitude': '143.0015',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '49'},
#               {'confidence': '86',
#                'datetime': '2023-03-11T14:24:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mr5',
#                'latitude': '-36.701',
#                'longitude': '142.538',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '56'},
#               {'confidence': '76',
#                'datetime': '2023-03-12T00:00:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1t8e',
#                'latitude': '-36.4553',
#                'longitude': '142.8786',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '49'},
#               {'confidence': '76',
#                'datetime': '2023-03-11T19:12:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mrv',
#                'latitude': '-36.5775',
#                'longitude': '142.6076',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '50'},
#               {'confidence': '70',
#                'datetime': '2023-03-12T04:48:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mre',
#                'latitude': '-36.6296',
#                'longitude': '142.5191',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '45'},
#               {'confidence': '55',
#                'datetime': '2023-03-12T00:00:00',
#                'geohash3': 'r1w',
#                'geohash5': 'r1w64',
#                'latitude': '-36.1858',
#                'longitude': '143.885',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '39'},
#               {'confidence': '70',
#                'datetime': '2023-03-12T09:36:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1tg4',
#                'latitude': '-36.0005',
#                'longitude': '143.1847',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '45'},
#               {'confidence': '86',
#                'datetime': '2023-03-12T04:48:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1t4x',
#                'latitude': '-36.0966',
#                'longitude': '142.3635',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '61'},
#               {'confidence': '64',
#                'datetime': '2023-03-12T14:24:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1x64',
#                'latitude': '-36.2032',
#                'longitude': '145.3025',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '42'}],
#  'latitude': '-38.167',
#  'longitude': '143.841',
#  'max_wind_speed': '11.1',
#  'precipitation ': ' 0.00G',
#  'producer': 'Climate',
#  'relative_humidity': '58.1',
#  'windspeed_knots': '5.3'}
# Batch 3853
# {'GHI_w/m2': '154',
#  'air_temperature_celcius': '20',
#  'date': '14/03/2023',
#  'fire_event': [],
#  'geohash3': 'r1n',
#  'geohash5': 'r1nqb',
#  'hotspots': [{'confidence': '68',
#                'datetime': '2023-03-12T09:36:00',
#                'geohash3': 'r1s',
#                'geohash5': 'r1s9u',
#                'latitude': '-36.2111',
#                'longitude': '141.505',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '44'},
#               {'confidence': '65',
#                'datetime': '2023-03-12T19:12:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1tu2',
#                'latitude': '-35.779',
#                'longitude': '143.1057',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '42'},
#               {'confidence': '53',
#                'datetime': '2023-03-12T14:24:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mru',
#                'latitude': '-36.5794',
#                'longitude': '142.5959',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '39'},
#               {'confidence': '74',
#                'datetime': '2023-03-13T00:00:00',
#                'geohash3': 'r1w',
#                'geohash5': 'r1w6f',
#                'latitude': '-36.0459',
#                'longitude': '143.8907',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '48'},
#               {'confidence': '96',
#                'datetime': '2023-03-12T19:12:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1t4x',
#                'latitude': '-36.1002',
#                'longitude': '142.3405',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '78'},
#               {'confidence': '74',
#                'datetime': '2023-03-13T04:48:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1t2g',
#                'latitude': '-36.404',
#                'longitude': '142.5467',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '48'},
#               {'confidence': '85',
#                'datetime': '2023-03-13T00:00:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1t92',
#                'latitude': '-36.3096',
#                'longitude': '142.7722',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '59'},
#               {'confidence': '83',
#                'datetime': '2023-03-13T09:36:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1t2u',
#                'latitude': '-36.4025',
#                'longitude': '142.5598',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '57'},
#               {'confidence': '83',
#                'datetime': '2023-03-13T14:24:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1t2h',
#                'latitude': '-36.5507',
#                'longitude': '142.5788',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '57'},
#               {'confidence': '61',
#                'datetime': '2023-03-13T04:48:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1tcz',
#                'latitude': '-36.2229',
#                'longitude': '143.4245',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '41'}],
#  'latitude': '-38.16',
#  'longitude': '143.803',
#  'max_wind_speed': '15',
#  'precipitation ': ' 0.00I',
#  'producer': 'Climate',
#  'relative_humidity': '62.2',
#  'windspeed_knots': '7.1'}
# Batch 3854
# {'GHI_w/m2': '199',
#  'air_temperature_celcius': '25',
#  'date': '15/03/2023',
#  'fire_event': [{'confidence': '62',
#                  'datetime': '2023-03-13T19:12:00',
#                  'fire_cause': 'natural',
#                  'hotspot_geohash5': 'r1mrd',
#                  'latitude': '-36.6312',
#                  'longitude': '142.5058',
#                  'surface_temperature_celcius': '41'},
#                 {'confidence': '77',
#                  'datetime': '2023-03-14T00:00:00',
#                  'fire_cause': 'natural',
#                  'hotspot_geohash5': 'r1mn2',
#                  'latitude': '-36.837',
#                  'longitude': '142.0391',
#                  'surface_temperature_celcius': '51'},
#                 {'confidence': 80.5,
#                  'datetime': '2023-03-14T09:36:00',
#                  'fire_cause': 'natural',
#                  'hotspot_geohash5': 'r1mr7',
#                  'latitude': '-36.6686',
#                  'longitude': '142.5195',
#                  'surface_temperature_celcius': 54.0}],
#  'geohash3': 'r1m',
#  'geohash5': 'r1mvu',
#  'hotspots': [{'confidence': '62',
#                'datetime': '2023-03-13T19:12:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mrd',
#                'latitude': '-36.6312',
#                'longitude': '142.5058',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '41'},
#               {'confidence': '52',
#                'datetime': '2023-03-13T09:36:00',
#                'geohash3': 'r1x',
#                'geohash5': 'r1xg4',
#                'latitude': '-36.0279',
#                'longitude': '146.0244',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '38'},
#               {'confidence': '77',
#                'datetime': '2023-03-14T00:00:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mn2',
#                'latitude': '-36.837',
#                'longitude': '142.0391',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '51'},
#               {'confidence': '81',
#                'datetime': '2023-03-13T14:24:00',
#                'geohash3': 'r1q',
#                'geohash5': 'r1qkx',
#                'latitude': '-37.1405',
#                'longitude': '144.1375',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '54'},
#               {'confidence': '79',
#                'datetime': '2023-03-14T04:48:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mr7',
#                'latitude': '-36.6732',
#                'longitude': '142.5162',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '52'},
#               {'confidence': '72',
#                'datetime': '2023-03-13T19:12:00',
#                'geohash3': 'r1q',
#                'geohash5': 'r1qck',
#                'latitude': '-37.7052',
#                'longitude': '144.6926',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '46'},
#               {'confidence': '82',
#                'datetime': '2023-03-14T09:36:00',
#                'geohash3': 'r1m',
#                'geohash5': 'r1mr7',
#                'latitude': '-36.6686',
#                'longitude': '142.5195',
#                'producer': 'AQUA',
#                'surface_temperature_celcius': '56'},
#               {'confidence': '78',
#                'datetime': '2023-03-14T00:00:00',
#                'geohash3': 'r1s',
#                'geohash5': 'r1s9g',
#                'latitude': '-36.2127',
#                'longitude': '141.4938',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '51'},
#               {'confidence': '85',
#                'datetime': '2023-03-14T04:48:00',
#                'geohash3': 'r1t',
#                'geohash5': 'r1t92',
#                'latitude': '-36.3114',
#                'longitude': '142.7605',
#                'producer': 'TERRA',
#                'surface_temperature_celcius': '59'}],
#  'latitude': '-36.942',
#  'longitude': '143.282',
#  'max_wind_speed': '13',
#  'precipitation ': ' 0.00I',
#  'producer': 'Climate',
#  'relative_humidity': '58.3',
#  'windspeed_knots': '7.1'}
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/opt/conda/lib/python3.8/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/opt/conda/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# Interrupted by CTRL-C. Stopping query.

# %%
# Print all documents in hist_data collection for checking (if required)
# cursor = collection.find({})
# for document in cursor: 
#     pprint(document)
